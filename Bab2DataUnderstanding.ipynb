# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Indonesian weather dataset
data = pd.read_csv("weatherAUS.csv")
data.head()
# Out:
#       Tanggal    Lokasi  SuhuMin  SuhuMax  CurahHujan  Penguapan  \
# 0  2010-04-30  Adelaide     10.8     21.2         0.0        1.8
# 1  2014-07-22  Adelaide      3.7     19.0         0.0        1.4
# 2  2014-07-23  Adelaide      9.6     15.8         0.0        2.6
# 3  2014-07-24  Adelaide     10.1     15.5        16.6        0.8
# 4  2014-07-25  Adelaide     11.2     16.2         1.8        0.6
#
#    SinarMatahari ArahAnginKencang  KecepatanAnginKencang ArahAnginJam9  ...  \
# 0           6.60              ENE                   22.0           ENE  ...
# 1           7.61                N                   24.0             N  ...
# 2           7.61               NE                   52.0           NNE  ...
# 3           7.61              NNE                   50.0            NW  ...
# 4           7.61               NW                   30.0           WNW  ...
#
#   KelembabanJam9  KelembabanJam3  TekananUdaraJam9  TekananUdaraJam3  \
# 0           66.0            48.0            1028.4            1024.7
# 1           75.0            32.0            1024.2            1021.1
# 2           35.0            51.0            1017.9            1011.5
# 3           96.0            80.0            1007.4            1008.0
# 4           89.0            70.0            1018.4            1019.2
#
#    AwanJam9  AwanJam3  SuhuJam9  SuhuJam3  HujanHariIni  HujanBesok
# 0      4.45      4.51      15.7      21.0            No          No
# 1      4.45      4.51       9.6      18.5            No          No
# 2      4.45      4.51      14.7      15.4            No         Yes
# 3      4.45      4.51      11.2      14.0           Yes         Yes
# 4      4.45      4.51      13.0      15.3           Yes         Yes
#
# [5 rows x 23 columns]

# %%
# Data Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Tanggal                145460 non-null  object
#  1   Lokasi                 145460 non-null  object
#  2   SuhuMin                145460 non-null  float64
#  3   SuhuMax                145460 non-null  float64
#  4   CurahHujan             145460 non-null  float64
#  5   Penguapan              145460 non-null  float64
#  6   SinarMatahari          145460 non-null  float64
#  7   ArahAnginKencang       145460 non-null  object
#  8   KecepatanAnginKencang  145460 non-null  float64
#  9   ArahAnginJam9          145460 non-null  object
#  10  ArahAnginJam3          145460 non-null  object
#  11  KecepatanAnginJam9     145460 non-null  float64
#  12  KecepatanAnginJam3     145460 non-null  float64
#  13  KelembabanJam9         145460 non-null  float64
#  14  KelembabanJam3         145460 non-null  float64
#  15  TekananUdaraJam9       145460 non-null  float64
#  16  TekananUdaraJam3       145460 non-null  float64
#  17  AwanJam9               145460 non-null  float64
#  18  AwanJam3               145460 non-null  float64
#  19  SuhuJam9               145460 non-null  float64
#  20  SuhuJam3               145460 non-null  float64
#  21  HujanHariIni           145460 non-null  object
#  22  HujanBesok             145460 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %%
# Data Describe
data.describe()
# Out:
#              SuhuMin        SuhuMax     CurahHujan      Penguapan  \
# count  145460.000000  145460.000000  145460.000000  145460.000000
# mean       12.193993      23.221337       2.360898       5.468995
# std         6.365750       7.088124       8.382488       3.161541
# min        -8.500000      -4.800000       0.000000       0.000000
# 25%         7.700000      18.000000       0.000000       4.000000
# 50%        12.100000      22.700000       0.000000       5.470000
# 75%        16.800000      28.200000       1.000000       5.470000
# max        33.900000      48.100000     371.000000     145.000000
#
#        SinarMatahari  KecepatanAnginKencang  KecepatanAnginJam9  \
# count  145460.000000          145460.000000       145460.000000
# mean        7.610612              40.035567           14.043384
# std         2.729486              13.118253            8.861059
# min         0.000000               6.000000            0.000000
# 25%         7.610000              31.000000            7.000000
# 50%         7.610000              39.000000           13.000000
# 75%         8.700000              46.000000           19.000000
# max        14.500000             135.000000          130.000000
#
#        KecepatanAnginJam3  KelembabanJam9  KelembabanJam3  TekananUdaraJam9  \
# count       145460.000000   145460.000000   145460.000000     145460.000000
# mean            18.662601       68.880816       51.539143       1017.649946
# std              8.716581       18.854765       20.471189          6.728467
# min              0.000000        0.000000        0.000000        980.500000
# 25%             13.000000       57.000000       37.000000       1013.500000
# 50%             18.660000       69.000000       51.540000       1017.650000
# 75%             24.000000       83.000000       65.000000       1021.800000
# max             87.000000      100.000000      100.000000       1041.000000
#
#        TekananUdaraJam3       AwanJam9       AwanJam3       SuhuJam9  \
# count     145460.000000  145460.000000  145460.000000  145460.000000
# mean        1015.256314       4.448437       4.509959      16.990624
# std            6.663973       2.265605       2.092954       6.449221
# min          977.100000       0.000000       0.000000      -7.200000
# 25%         1011.100000       3.000000       4.000000      12.300000
# 50%         1015.260000       4.450000       4.510000      16.800000
# 75%         1019.400000       6.000000       6.000000      21.500000
# max         1039.600000       9.000000       9.000000      40.200000
#
#             SuhuJam3
# count  145460.000000
# mean       21.683306
# std         6.850057
# min        -5.400000
# 25%        16.700000
# 50%        21.400000
# 75%        26.200000
# max        46.700000

# %%
# Missing value analysis (isnull().sum())
missing_values = data.isnull().sum().sort_values(ascending=False)
print(missing_values)
# Out:
# Tanggal                  0
# Lokasi                   0
# SuhuMin                  0
# SuhuMax                  0
# CurahHujan               0
# Penguapan                0
# SinarMatahari            0
# ArahAnginKencang         0
# KecepatanAnginKencang    0
# ArahAnginJam9            0
# ArahAnginJam3            0
# KecepatanAnginJam9       0
# KecepatanAnginJam3       0
# KelembabanJam9           0
# KelembabanJam3           0
# TekananUdaraJam9         0
# TekananUdaraJam3         0
# AwanJam9                 0
# AwanJam3                 0
# SuhuJam9                 0
# SuhuJam3                 0
# HujanHariIni             0
# HujanBesok               0
# dtype: int64

# %%
# Distribusi Variabel Numerik
data[['SuhuMin','SuhuMax','CurahHujan','Penguapan','SinarMatahari','KecepatanAnginKencang']].hist(
    figsize=(10,8), bins=20, color='skyblue', edgecolor='black')
plt.suptitle("Distribusi Variabel Numerik Utama", fontsize=14)
plt.show()

# %%
# Deteksi Outlier Pada Variabel Curah Hujan
plt.figure(figsize=(8,4))
sns.boxplot(x=data['CurahHujan'], color='skyblue')
plt.title("Deteksi Outlier pada Variabel CurahHujan")
plt.xlabel("CurahHujan (mm)")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

data = pd.read_csv("weatherAUS.csv")

# Convert 'RainTomorrow' to numeric using Label Encoding
le = LabelEncoder()
data['HujanBesok_encoded'] = le.fit_transform(data['HujanBesok'])

# Calculate correlation for numeric columns including the encoded target variable
corr_with_target = data.corr(numeric_only=True)['HujanBesok_encoded'].sort_values(ascending=False)

# Display the correlation with the encoded target variable
print("Korelasi Variabel Numerik terhadap HujanBesok (Encoded):")
display(corr_with_target)

# Optional: Visualize the correlation with the encoded target variable
plt.figure(figsize=(10,6))
corr_with_target.drop('HujanBesok_encoded').plot(kind='bar', color='skyblue')
plt.title("Korelasi Variabel Numerik terhadap HujanBesok (Encoded)")
plt.xlabel("Variabel")
plt.ylabel("Nilai Korelasi")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Korelasi Variabel Numerik terhadap HujanBesok (Encoded):
# HujanBesok_encoded       1.000000
# KelembabanJam3           0.433179
# AwanJam3                 0.298049
# KelembabanJam9           0.251470
# AwanJam9                 0.249960
# CurahHujan               0.233900
# KecepatanAnginKencang    0.220443
# KecepatanAnginJam9       0.086661
# KecepatanAnginJam3       0.084207
# SuhuMin                  0.082175
# SuhuJam9                -0.025555
# Penguapan               -0.088286
# SuhuMax                 -0.156850
# SuhuJam3                -0.187806
# TekananUdaraJam3        -0.211979
# TekananUdaraJam9        -0.230975
# SinarMatahari           -0.321532
# Name: HujanBesok_encoded, dtype: float64

# %%
# Distribusi Variabel Target (RainTomorrow)
plt.figure(figsize=(6,4))
sns.countplot(x='HujanBesok', data=data, palette='pastel')
plt.title("Distribusi Variabel Target - HujanBesok")
plt.xlabel("Apakah Hujan Besok?")
plt.ylabel("Jumlah Data")
plt.show()

print("Proporsi tiap kelas HujanBesok (%):")
print(data['HujanBesok'].value_counts(normalize=True) * 100)
# Out:
# C:\Users\MyBook Hype AMD\AppData\Local\Temp\ipykernel_14488\3802700212.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='HujanBesok', data=data, palette='pastel')
# Proporsi tiap kelas HujanBesok (%):
# HujanBesok
# No     78.085384
# Yes    21.914616
# Name: proportion, dtype: float64
